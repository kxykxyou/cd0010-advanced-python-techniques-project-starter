# %%
import pandas as pd
import json
neos = pd.read_csv('data/neos.csv')
with open('data/cad.json') as infile:
    content = json.load(infile)
cads = pd.DataFrame(content['data'], columns = content['fields'])
# Out:
# /Users/shyanechang/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4,5,16,23,24,70) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cads[cads.cd.str.startswith('2020-Jan-01')]
# Out:
#                des orbit_id                 jd                 cd  \
# 248032    2020 AY1       18  2458849.537524496  2020-Jan-01 00:54
# 248033     2019 YK       10  2458849.587205145  2020-Jan-01 02:06
# 248034   2013 EC20       13  2458849.646807170  2020-Jan-01 03:31
# 248035    2020 AM1        5  2458849.804441448  2020-Jan-01 07:18
# 248036  2016 EF195        9  2458849.864077373  2020-Jan-01 08:44
# 248037    2020 AP3        3  2458849.967321891  2020-Jan-01 11:13
# 248038   2011 YE40        5  2458850.108385269  2020-Jan-01 14:36
# 248039    2019 WE5       14  2458850.121465095  2020-Jan-01 14:55
# 248040    2020 AE2        1  2458850.136305619  2020-Jan-01 15:16
# 248041     2020 JU       23  2458850.375381369  2020-Jan-01 21:01
# 248042    2020 AN2        1  2458850.387698740  2020-Jan-01 21:18
# 248043   2011 HS60       16  2458850.416011037  2020-Jan-01 21:59
# 248044     2020 AX        5  2458850.450408128  2020-Jan-01 22:49
#
# ...

# %%
neos[neos.pdes == '2020 AY1']
# Out:
#              id    spkid          full_name      pdes name prefix neo pha  \
# 21765  bK20A01Y  3976542         (2020 AY1)  2020 AY1  NaN    NaN   Y   N
#
#           H   G  ...  n_obs_used  n_del_obs_used  n_dop_obs_used  \
# 21765  25.1 NaN  ...         129             NaN             NaN
#
#        condition_code      rms  two_body  A1  A2  A3  DT
# 21765             4.0  0.48003       NaN NaN NaN NaN NaN
#
# [1 rows x 75 columns]
